# %% [markdown]
# # Import Required Libraries
# Import the necessary libraries, including Folium and Pandas.

# %%
# Import Required Libraries
import folium
from folium.plugins import MarkerCluster
import pandas as pd

# %% [markdown]
# # Create an Interactive Map
# Use `folium.Map()` to create a map centered on your city.

# %%
# Create an Interactive Map
mapa = folium.Map(location=[38.7169, -9.1399], zoom_start=12, tiles='CartoDB positron')  # Centered on Lisbon
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb07860fe97cfb30d33d48a50ddc404a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb07860fe97cfb30d33d48a50ddc404a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb07860fe97cfb30d33d48a50ddc404a = L.map(
#                 &quot;map_cb07860fe97cfb30d33d48a50ddc404a&quot;,
#                 {
#                     center: [38.7169, -9.1399],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_db018298bfc8cfa7c1fa16698b9ef526 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_db018298bfc8cfa7c1fa16698b9ef526.addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Add Markers for Tourist Locations
# Add 5 markers to the map using `folium.Marker()` with `popup` and `tooltip`.

# %%
# Add Markers for Tourist Locations
locais_turisticos = [
    {"nome": "Torre de Belém", "latitude": 38.6916, "longitude": -9.2150},
    {"nome": "Mosteiro dos Jerónimos", "latitude": 38.6972, "longitude": -9.2065},
    {"nome": "Castelo de São Jorge", "latitude": 38.7139, "longitude": -9.1335},
    {"nome": "Praça do Comércio", "latitude": 38.7078, "longitude": -9.1366},
    {"nome": "Oceanário de Lisboa", "latitude": 38.7636, "longitude": -9.0931}
]

for local in locais_turisticos:
    folium.Marker(
        location=[local["latitude"], local["longitude"]],
        popup=f"{local['nome']}",
        tooltip=local["nome"]
    ).add_to(mapa)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb07860fe97cfb30d33d48a50ddc404a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb07860fe97cfb30d33d48a50ddc404a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb07860fe97cfb30d33d48a50ddc404a = L.map(
#                 &quot;map_cb07860fe97cfb30d33d48a50ddc404a&quot;,
#                 {
#                     center: [38.7169, -9.1399],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_db018298bfc8cfa7c1fa16698b9ef526 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_db018298bfc8cfa7c1fa16698b9ef526.addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#             tile_layer_db018298bfc8cfa7c1fa16698b9ef526.addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#             var marker_37352640aa66320daa8b17014fab360b = L.marker(
#                 [38.6916, -9.215],
#                 {
# }
#             ).addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#         var popup_9c52efd7e2b9f26d171a4b83464e539c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_58e0ac39c6f0645af84e319cf996d140 = $(`&lt;div id=&quot;html_58e0ac39c6f0645af84e319cf996d140&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Torre de Belém&lt;/div&gt;`)[0];
#                 popup_9c52efd7e2b9f26d171a4b83464e539c.setContent(html_58e0ac39c6f0645af84e319cf996d140);
#
#
#
#         marker_37352640aa66320daa8b17014fab360b.bindPopup(popup_9c52efd7e2b9f26d171a4b83464e539c)
#         ;
#
#
#
#
#             marker_37352640aa66320daa8b17014fab360b.bindTooltip(
#                 `&lt;div&gt;
#                      Torre de Belém
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_43b79ee69a0bde937765aa580df3f55d = L.marker(
#                 [38.6972, -9.2065],
#                 {
# }
#             ).addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#         var popup_48e0ac46768163eefc8ac0acce9871e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_942bb967a552f283c2d59bf08a2994ac = $(`&lt;div id=&quot;html_942bb967a552f283c2d59bf08a2994ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mosteiro dos Jerónimos&lt;/div&gt;`)[0];
#                 popup_48e0ac46768163eefc8ac0acce9871e7.setContent(html_942bb967a552f283c2d59bf08a2994ac);
#
#
#
#         marker_43b79ee69a0bde937765aa580df3f55d.bindPopup(popup_48e0ac46768163eefc8ac0acce9871e7)
#         ;
#
#
#
#
#             marker_43b79ee69a0bde937765aa580df3f55d.bindTooltip(
#                 `&lt;div&gt;
#                      Mosteiro dos Jerónimos
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_683220093931f941c3a2d396b49e0d82 = L.marker(
#                 [38.7139, -9.1335],
#                 {
# }
#             ).addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#         var popup_5bd6a634b92f8d7fcc260ac701004edc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb10ffb6f6ed759b0a74048eb7e5c72f = $(`&lt;div id=&quot;html_cb10ffb6f6ed759b0a74048eb7e5c72f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Castelo de São Jorge&lt;/div&gt;`)[0];
#                 popup_5bd6a634b92f8d7fcc260ac701004edc.setContent(html_cb10ffb6f6ed759b0a74048eb7e5c72f);
#
#
#
#         marker_683220093931f941c3a2d396b49e0d82.bindPopup(popup_5bd6a634b92f8d7fcc260ac701004edc)
#         ;
#
#
#
#
#             marker_683220093931f941c3a2d396b49e0d82.bindTooltip(
#                 `&lt;div&gt;
#                      Castelo de São Jorge
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_afab9a952524c1d7fa2d9c04ed4a67ab = L.marker(
#                 [38.7078, -9.1366],
#                 {
# }
#             ).addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#         var popup_75c4b7a630d84e4b145e7c3cfc5ba84d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4071ae31a402d665dcb42fd6f585c3fd = $(`&lt;div id=&quot;html_4071ae31a402d665dcb42fd6f585c3fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Praça do Comércio&lt;/div&gt;`)[0];
#                 popup_75c4b7a630d84e4b145e7c3cfc5ba84d.setContent(html_4071ae31a402d665dcb42fd6f585c3fd);
#
#
#
#         marker_afab9a952524c1d7fa2d9c04ed4a67ab.bindPopup(popup_75c4b7a630d84e4b145e7c3cfc5

# %% [markdown]
# # Group Markers with MarkerCluster
# Use `MarkerCluster()` to group the markers on the map.

# %%
# Group Markers with MarkerCluster
cluster = MarkerCluster().add_to(mapa)

for local in locais_turisticos:
    folium.Marker(
        location=[local["latitude"], local["longitude"]],
        popup=f"{local['nome']}",
        tooltip=local["nome"]
    ).add_to(cluster)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb07860fe97cfb30d33d48a50ddc404a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb07860fe97cfb30d33d48a50ddc404a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb07860fe97cfb30d33d48a50ddc404a = L.map(
#                 &quot;map_cb07860fe97cfb30d33d48a50ddc404a&quot;,
#                 {
#                     center: [38.7169, -9.1399],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_db018298bfc8cfa7c1fa16698b9ef526 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_db018298bfc8cfa7c1fa16698b9ef526.addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#             tile_layer_db018298bfc8cfa7c1fa16698b9ef526.addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#             var marker_37352640aa66320daa8b17014fab360b = L.marker(
#                 [38.6916, -9.215],
#                 {
# }
#             ).addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#         var popup_9c52efd7e2b9f26d171a4b83464e539c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_58e0ac39c6f0645af84e319cf996d140 = $(`&lt;div id=&quot;html_58e0ac39c6f0645af84e319cf996d140&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Torre de Belém&lt;/div&gt;`)[0];
#                 popup_9c52efd7e2b9f26d171a4b83464e539c.setContent(html_58e0ac39c6f0645af84e319cf996d140);
#
#
#
#         marker_37352640aa66320daa8b17014fab360b.bindPopup(popup_9c52efd7e2b9f26d171a4b83464e539c)
#         ;
#
#
#
#
#             marker_37352640aa66320daa8b17014fab360b.bindTooltip(
#                 `&lt;div&gt;
#                      Torre de Belém
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_43b79ee69a0bde937765aa580df3f55d = L.marker(
#                 [38.6972, -9.2065],
#                 {
# }
#             ).addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#         var popup_48e0ac46768163eefc8ac0acce9871e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_942bb967a552f283c2d59bf08a2994ac = $(`&lt;div id=&quot;html_942bb967a552f283c2d59bf08a2994ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mosteiro dos Jerónimos&lt;/div&gt;`)[0];
#                 popup_48e0ac46768163eefc8ac0acce9871e7.setContent(html_942bb967a552f283c2d59bf08a2994ac);
#
#
#
#         marker_43b79ee69a0bde937765aa580df3f55d.bindPopup(popup_48e0ac46768163eefc8ac0acce9871e7)
#         ;
#
#
#
#
#             marker_43b79ee69a0bde937765aa580df3f55d.bindTooltip(
#                 `&lt;div&gt;
#                      Mosteiro dos Jerónimos
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_683220093931f941c3a2d396b49e0d82 = L.marker(
#                 [38.7139, -9.1335],
#                 {
# }
#             ).addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#         var popup_5bd6a634b92f8d7fcc260ac701004edc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb10ffb6f6ed759b0a74048eb7e5c72f = $(`&lt;div id=&quot;html_cb10ffb6f6ed759b0a74048eb7e5c72f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Castelo de São Jorge&lt;/div&gt;`)[0];
#                 popup_5bd6a634b92f8d7fcc260ac701004edc.setContent(html_cb10ffb6f6ed759b0a74048eb7e5c72f);
#
#
#
#         marker_683220093931f941c3a2d396b49e0d82.bindPopup(popup_5bd6a634b92f8d7fcc260ac701004edc)
#         ;
#
#
#
#
#             marker_683220093931f941c3a2d396b49e0d82.bindTooltip(
#                 `&lt;div&gt;
#                      Castelo de São Jorge
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_afab9a952524c1d7fa2d9c04ed4a67ab = L.marker(
#                 [38.7078, -9.1366],
#                 {
# }
#             ).addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#         var popup_75c4b7a630d84e4b145e7c3cfc5ba84d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });

# %% [markdown]
# # Add a Colored Circle
# Use `folium.Circle()` to add a colored circle around one of the locations.

# %%
# Add a Colored Circle
folium.Circle(
    location=[38.6916, -9.2150],  # Torre de Belém
    radius=500,
    color='blue',
    fill=True,
    fill_color='blue',
    fill_opacity=0.5,
    tooltip="Área de Interesse"
).add_to(mapa)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb07860fe97cfb30d33d48a50ddc404a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb07860fe97cfb30d33d48a50ddc404a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb07860fe97cfb30d33d48a50ddc404a = L.map(
#                 &quot;map_cb07860fe97cfb30d33d48a50ddc404a&quot;,
#                 {
#                     center: [38.7169, -9.1399],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_db018298bfc8cfa7c1fa16698b9ef526 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_db018298bfc8cfa7c1fa16698b9ef526.addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#             tile_layer_db018298bfc8cfa7c1fa16698b9ef526.addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#             var marker_37352640aa66320daa8b17014fab360b = L.marker(
#                 [38.6916, -9.215],
#                 {
# }
#             ).addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#         var popup_9c52efd7e2b9f26d171a4b83464e539c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_58e0ac39c6f0645af84e319cf996d140 = $(`&lt;div id=&quot;html_58e0ac39c6f0645af84e319cf996d140&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Torre de Belém&lt;/div&gt;`)[0];
#                 popup_9c52efd7e2b9f26d171a4b83464e539c.setContent(html_58e0ac39c6f0645af84e319cf996d140);
#
#
#
#         marker_37352640aa66320daa8b17014fab360b.bindPopup(popup_9c52efd7e2b9f26d171a4b83464e539c)
#         ;
#
#
#
#
#             marker_37352640aa66320daa8b17014fab360b.bindTooltip(
#                 `&lt;div&gt;
#                      Torre de Belém
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_43b79ee69a0bde937765aa580df3f55d = L.marker(
#                 [38.6972, -9.2065],
#                 {
# }
#             ).addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#         var popup_48e0ac46768163eefc8ac0acce9871e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_942bb967a552f283c2d59bf08a2994ac = $(`&lt;div id=&quot;html_942bb967a552f283c2d59bf08a2994ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mosteiro dos Jerónimos&lt;/div&gt;`)[0];
#                 popup_48e0ac46768163eefc8ac0acce9871e7.setContent(html_942bb967a552f283c2d59bf08a2994ac);
#
#
#
#         marker_43b79ee69a0bde937765aa580df3f55d.bindPopup(popup_48e0ac46768163eefc8ac0acce9871e7)
#         ;
#
#
#
#
#             marker_43b79ee69a0bde937765aa580df3f55d.bindTooltip(
#                 `&lt;div&gt;
#                      Mosteiro dos Jerónimos
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_683220093931f941c3a2d396b49e0d82 = L.marker(
#                 [38.7139, -9.1335],
#                 {
# }
#             ).addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#         var popup_5bd6a634b92f8d7fcc260ac701004edc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb10ffb6f6ed759b0a74048eb7e5c72f = $(`&lt;div id=&quot;html_cb10ffb6f6ed759b0a74048eb7e5c72f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Castelo de São Jorge&lt;/div&gt;`)[0];
#                 popup_5bd6a634b92f8d7fcc260ac701004edc.setContent(html_cb10ffb6f6ed759b0a74048eb7e5c72f);
#
#
#
#         marker_683220093931f941c3a2d396b49e0d82.bindPopup(popup_5bd6a634b92f8d7fcc260ac701004edc)
#         ;
#
#
#
#
#             marker_683220093931f941c3a2d396b49e0d82.bindTooltip(
#                 `&lt;div&gt;
#                      Castelo de São Jorge
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_afab9a952524c1d7fa2d9c04ed4a67ab = L.marker(
#                 [38.7078, -9.1366],
#                 {
# }
#             ).addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#         var popup_75c4b7a630d84e4b145e7c3cfc5ba84d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });

# %% [markdown]
# # Use FeatureGroup for Categorization
# Use `folium.FeatureGroup()` to separate locations into categories like museums and parks.

# %%
# Use FeatureGroup for Categorization
museus = folium.FeatureGroup(name="Museus").add_to(mapa)
parques = folium.FeatureGroup(name="Parques").add_to(mapa)

folium.Marker(
    location=[38.6972, -9.2065],  # Mosteiro dos Jerónimos
    popup="Mosteiro dos Jerónimos",
    tooltip="Mosteiro dos Jerónimos"
).add_to(museus)

folium.Marker(
    location=[38.7636, -9.0931],  # Oceanário de Lisboa
    popup="Oceanário de Lisboa",
    tooltip="Oceanário de Lisboa"
).add_to(parques)

folium.LayerControl().add_to(mapa)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb07860fe97cfb30d33d48a50ddc404a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb07860fe97cfb30d33d48a50ddc404a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb07860fe97cfb30d33d48a50ddc404a = L.map(
#                 &quot;map_cb07860fe97cfb30d33d48a50ddc404a&quot;,
#                 {
#                     center: [38.7169, -9.1399],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_db018298bfc8cfa7c1fa16698b9ef526 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_db018298bfc8cfa7c1fa16698b9ef526.addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#             tile_layer_db018298bfc8cfa7c1fa16698b9ef526.addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#             var marker_37352640aa66320daa8b17014fab360b = L.marker(
#                 [38.6916, -9.215],
#                 {
# }
#             ).addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#         var popup_9c52efd7e2b9f26d171a4b83464e539c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_58e0ac39c6f0645af84e319cf996d140 = $(`&lt;div id=&quot;html_58e0ac39c6f0645af84e319cf996d140&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Torre de Belém&lt;/div&gt;`)[0];
#                 popup_9c52efd7e2b9f26d171a4b83464e539c.setContent(html_58e0ac39c6f0645af84e319cf996d140);
#
#
#
#         marker_37352640aa66320daa8b17014fab360b.bindPopup(popup_9c52efd7e2b9f26d171a4b83464e539c)
#         ;
#
#
#
#
#             marker_37352640aa66320daa8b17014fab360b.bindTooltip(
#                 `&lt;div&gt;
#                      Torre de Belém
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_43b79ee69a0bde937765aa580df3f55d = L.marker(
#                 [38.6972, -9.2065],
#                 {
# }
#             ).addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#         var popup_48e0ac46768163eefc8ac0acce9871e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_942bb967a552f283c2d59bf08a2994ac = $(`&lt;div id=&quot;html_942bb967a552f283c2d59bf08a2994ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mosteiro dos Jerónimos&lt;/div&gt;`)[0];
#                 popup_48e0ac46768163eefc8ac0acce9871e7.setContent(html_942bb967a552f283c2d59bf08a2994ac);
#
#
#
#         marker_43b79ee69a0bde937765aa580df3f55d.bindPopup(popup_48e0ac46768163eefc8ac0acce9871e7)
#         ;
#
#
#
#
#             marker_43b79ee69a0bde937765aa580df3f55d.bindTooltip(
#                 `&lt;div&gt;
#                      Mosteiro dos Jerónimos
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_683220093931f941c3a2d396b49e0d82 = L.marker(
#                 [38.7139, -9.1335],
#                 {
# }
#             ).addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#         var popup_5bd6a634b92f8d7fcc260ac701004edc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb10ffb6f6ed759b0a74048eb7e5c72f = $(`&lt;div id=&quot;html_cb10ffb6f6ed759b0a74048eb7e5c72f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Castelo de São Jorge&lt;/div&gt;`)[0];
#                 popup_5bd6a634b92f8d7fcc260ac701004edc.setContent(html_cb10ffb6f6ed759b0a74048eb7e5c72f);
#
#
#
#         marker_683220093931f941c3a2d396b49e0d82.bindPopup(popup_5bd6a634b92f8d7fcc260ac701004edc)
#         ;
#
#
#
#
#             marker_683220093931f941c3a2d396b49e0d82.bindTooltip(
#                 `&lt;div&gt;
#                      Castelo de São Jorge
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_afab9a952524c1d7fa2d9c04ed4a67ab = L.marker(
#                 [38.7078, -9.1366],
#                 {
# }
#             ).addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#         var popup_75c4b7a630d84e4b145e7c3cfc5ba84d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });

# %% [markdown]
# # Load GeoJSON File
# Load a GeoJSON file with district or region boundaries using `folium.GeoJson()`.

# %%
# Load GeoJSON File
geojson_data = {
    "type": "FeatureCollection",
    "features": [
        {
            "type": "Feature",
            "properties": {"Distrito": "Lisboa"},
            "geometry": {
                "type": "Polygon",
                "coordinates": [[
                    [-9.3, 38.8],
                    [-9.1, 38.8],
                    [-9.1, 38.6],
                    [-9.3, 38.6],
                    [-9.3, 38.8]
                ]]
            }
        }
    ]
}

folium.GeoJson(
    geojson_data,
    name="Limites de Lisboa"
).add_to(mapa)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb07860fe97cfb30d33d48a50ddc404a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb07860fe97cfb30d33d48a50ddc404a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb07860fe97cfb30d33d48a50ddc404a = L.map(
#                 &quot;map_cb07860fe97cfb30d33d48a50ddc404a&quot;,
#                 {
#                     center: [38.7169, -9.1399],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_db018298bfc8cfa7c1fa16698b9ef526 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_db018298bfc8cfa7c1fa16698b9ef526.addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#             tile_layer_db018298bfc8cfa7c1fa16698b9ef526.addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#             var marker_37352640aa66320daa8b17014fab360b = L.marker(
#                 [38.6916, -9.215],
#                 {
# }
#             ).addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#         var popup_9c52efd7e2b9f26d171a4b83464e539c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_58e0ac39c6f0645af84e319cf996d140 = $(`&lt;div id=&quot;html_58e0ac39c6f0645af84e319cf996d140&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Torre de Belém&lt;/div&gt;`)[0];
#                 popup_9c52efd7e2b9f26d171a4b83464e539c.setContent(html_58e0ac39c6f0645af84e319cf996d140);
#
#
#
#         marker_37352640aa66320daa8b17014fab360b.bindPopup(popup_9c52efd7e2b9f26d171a4b83464e539c)
#         ;
#
#
#
#
#             marker_37352640aa66320daa8b17014fab360b.bindTooltip(
#                 `&lt;div&gt;
#                      Torre de Belém
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_43b79ee69a0bde937765aa580df3f55d = L.marker(
#                 [38.6972, -9.2065],
#                 {
# }
#             ).addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#         var popup_48e0ac46768163eefc8ac0acce9871e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_942bb967a552f283c2d59bf08a2994ac = $(`&lt;div id=&quot;html_942bb967a552f283c2d59bf08a2994ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mosteiro dos Jerónimos&lt;/div&gt;`)[0];
#                 popup_48e0ac46768163eefc8ac0acce9871e7.setContent(html_942bb967a552f283c2d59bf08a2994ac);
#
#
#
#         marker_43b79ee69a0bde937765aa580df3f55d.bindPopup(popup_48e0ac46768163eefc8ac0acce9871e7)
#         ;
#
#
#
#
#             marker_43b79ee69a0bde937765aa580df3f55d.bindTooltip(
#                 `&lt;div&gt;
#                      Mosteiro dos Jerónimos
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_683220093931f941c3a2d396b49e0d82 = L.marker(
#                 [38.7139, -9.1335],
#                 {
# }
#             ).addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#         var popup_5bd6a634b92f8d7fcc260ac701004edc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb10ffb6f6ed759b0a74048eb7e5c72f = $(`&lt;div id=&quot;html_cb10ffb6f6ed759b0a74048eb7e5c72f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Castelo de São Jorge&lt;/div&gt;`)[0];
#                 popup_5bd6a634b92f8d7fcc260ac701004edc.setContent(html_cb10ffb6f6ed759b0a74048eb7e5c72f);
#
#
#
#         marker_683220093931f941c3a2d396b49e0d82.bindPopup(popup_5bd6a634b92f8d7fcc260ac701004edc)
#         ;
#
#
#
#
#             marker_683220093931f941c3a2d396b49e0d82.bindTooltip(
#                 `&lt;div&gt;
#                      Castelo de São Jorge
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_afab9a952524c1d7fa2d9c04ed4a67ab = L.marker(
#                 [38.7078, -9.1366],
#                 {
# }
#             ).addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#         var popup_75c4b7a630d84e4b145e7c3cfc5ba84d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });

# %% [markdown]
# # Create a Choropleth Map
# Use `folium.Choropleth()` to create a choropleth map with population data.

# %%
# Create a Choropleth Map
populacao_df = pd.DataFrame({
    "Distrito": ["Lisboa"],
    "População": [500000]
})

folium.Choropleth(
    geo_data=geojson_data,
    name="População por Distrito",
    data=populacao_df,
    columns=["Distrito", "População"],
    key_on="feature.properties.Distrito",
    fill_color="YlOrRd",
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name="População"
).add_to(mapa)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb07860fe97cfb30d33d48a50ddc404a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb07860fe97cfb30d33d48a50ddc404a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb07860fe97cfb30d33d48a50ddc404a = L.map(
#                 &quot;map_cb07860fe97cfb30d33d48a50ddc404a&quot;,
#                 {
#                     center: [38.7169, -9.1399],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_db018298bfc8cfa7c1fa16698b9ef526 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_db018298bfc8cfa7c1fa16698b9ef526.addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#             tile_layer_db018298bfc8cfa7c1fa16698b9ef526.addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#             var marker_37352640aa66320daa8b17014fab360b = L.marker(
#                 [38.6916, -9.215],
#                 {
# }
#             ).addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#         var popup_9c52efd7e2b9f26d171a4b83464e539c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_58e0ac39c6f0645af84e319cf996d140 = $(`&lt;div id=&quot;html_58e0ac39c6f0645af84e319cf996d140&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Torre de Belém&lt;/div&gt;`)[0];
#                 popup_9c52efd7e2b9f26d171a4b83464e539c.setContent(html_58e0ac39c6f0645af84e319cf996d140);
#
#
#
#         marker_37352640aa66320daa8b17014fab360b.bindPopup(popup_9c52efd7e2b9f26d171a4b83464e539c)
#         ;
#
#
#
#
#             marker_37352640aa66320daa8b17014fab360b.bindTooltip(
#                 `&lt;div&gt;
#                      Torre de Belém
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_43b79ee69a0bde937765aa580df3f55d = L.marker(
#                 [38.6972, -9.2065],
#                 {
# }
#             ).addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#         var popup_48e0ac46768163eefc8ac0acce9871e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_942bb967a552f283c2d59bf08a2994ac = $(`&lt;div id=&quot;html_942bb967a552f283c2d59bf08a2994ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mosteiro dos Jerónimos&lt;/div&gt;`)[0];
#                 popup_48e0ac46768163eefc8ac0acce9871e7.setContent(html_942bb967a552f283c2d59bf08a2994ac);
#
#
#
#         marker_43b79ee69a0bde937765aa580df3f55d.bindPopup(popup_48e0ac46768163eefc8ac0acce9871e7)
#         ;
#
#
#
#
#             marker_43b79ee69a0bde937765aa580df3f55d.bindTooltip(
#                 `&lt;div&gt;
#                      Mosteiro dos Jerónimos
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_683220093931f941c3a2d396b49e0d82 = L.marker(
#                 [38.7139, -9.1335],
#                 {
# }
#             ).addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#         var popup_5bd6a634b92f8d7fcc260ac701004edc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb10ffb6f6ed759b0a74048eb7e5c72f = $(`&lt;div id=&quot;html_cb10ffb6f6ed759b0a74048eb7e5c72f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Castelo de São Jorge&lt;/div&gt;`)[0];
#                 popup_5bd6a634b92f8d7fcc260ac701004edc.setContent(html_cb10ffb6f6ed759b0a74048eb7e5c72f);
#
#
#
#         marker_683220093931f941c3a2d396b49e0d82.bindPopup(popup_5bd6a634b92f8d7fcc260ac701004edc)
#         ;
#
#
#
#
#             marker_683220093931f941c3a2d396b49e0d82.bindTooltip(
#                 `&lt;div&gt;
#                      Castelo de São Jorge
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_afab9a952524c1d7fa2d9c04ed4a67ab = L.marker(
#                 [38.7078, -9.1366],
#                 {
# }
#             ).addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#         var

# %% [markdown]
# # Customize Choropleth Colors
# Change the color scheme of the choropleth map to `'BuPu'` and adjust opacity.

# %%
# Customize Choropleth Colors
folium.Choropleth(
    geo_data=geojson_data,
    name="População por Distrito (BuPu)",
    data=populacao_df,
    columns=["Distrito", "População"],
    key_on="feature.properties.Distrito",
    fill_color="BuPu",
    fill_opacity=0.8,
    line_opacity=0.3,
    legend_name="População"
).add_to(mapa)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb07860fe97cfb30d33d48a50ddc404a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb07860fe97cfb30d33d48a50ddc404a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb07860fe97cfb30d33d48a50ddc404a = L.map(
#                 &quot;map_cb07860fe97cfb30d33d48a50ddc404a&quot;,
#                 {
#                     center: [38.7169, -9.1399],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_db018298bfc8cfa7c1fa16698b9ef526 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_db018298bfc8cfa7c1fa16698b9ef526.addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#             tile_layer_db018298bfc8cfa7c1fa16698b9ef526.addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#             var marker_37352640aa66320daa8b17014fab360b = L.marker(
#                 [38.6916, -9.215],
#                 {
# }
#             ).addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#         var popup_9c52efd7e2b9f26d171a4b83464e539c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_58e0ac39c6f0645af84e319cf996d140 = $(`&lt;div id=&quot;html_58e0ac39c6f0645af84e319cf996d140&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Torre de Belém&lt;/div&gt;`)[0];
#                 popup_9c52efd7e2b9f26d171a4b83464e539c.setContent(html_58e0ac39c6f0645af84e319cf996d140);
#
#
#
#         marker_37352640aa66320daa8b17014fab360b.bindPopup(popup_9c52efd7e2b9f26d171a4b83464e539c)
#         ;
#
#
#
#
#             marker_37352640aa66320daa8b17014fab360b.bindTooltip(
#                 `&lt;div&gt;
#                      Torre de Belém
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_43b79ee69a0bde937765aa580df3f55d = L.marker(
#                 [38.6972, -9.2065],
#                 {
# }
#             ).addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#         var popup_48e0ac46768163eefc8ac0acce9871e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_942bb967a552f283c2d59bf08a2994ac = $(`&lt;div id=&quot;html_942bb967a552f283c2d59bf08a2994ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mosteiro dos Jerónimos&lt;/div&gt;`)[0];
#                 popup_48e0ac46768163eefc8ac0acce9871e7.setContent(html_942bb967a552f283c2d59bf08a2994ac);
#
#
#
#         marker_43b79ee69a0bde937765aa580df3f55d.bindPopup(popup_48e0ac46768163eefc8ac0acce9871e7)
#         ;
#
#
#
#
#             marker_43b79ee69a0bde937765aa580df3f55d.bindTooltip(
#                 `&lt;div&gt;
#                      Mosteiro dos Jerónimos
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_683220093931f941c3a2d396b49e0d82 = L.marker(
#                 [38.7139, -9.1335],
#                 {
# }
#             ).addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#         var popup_5bd6a634b92f8d7fcc260ac701004edc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb10ffb6f6ed759b0a74048eb7e5c72f = $(`&lt;div id=&quot;html_cb10ffb6f6ed759b0a74048eb7e5c72f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Castelo de São Jorge&lt;/div&gt;`)[0];
#                 popup_5bd6a634b92f8d7fcc260ac701004edc.setContent(html_cb10ffb6f6ed759b0a74048eb7e5c72f);
#
#
#
#         marker_683220093931f941c3a2d396b49e0d82.bindPopup(popup_5bd6a634b92f8d7fcc260ac701004edc)
#         ;
#
#
#
#
#             marker_683220093931f941c3a2d396b49e0d82.bindTooltip(
#                 `&lt;div&gt;
#                      Castelo de São Jorge
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_afab9a952524c1d7fa2d9c04ed4a67ab = L.marker(
#                 [38.7078, -9.1366],
#                 {
# }
#             ).addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#         var

# %% [markdown]
# # Add LayerControl
# Add `folium.LayerControl()` to toggle between different layers on the map.

# %%
# Add LayerControl
folium.LayerControl().add_to(mapa)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb07860fe97cfb30d33d48a50ddc404a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb07860fe97cfb30d33d48a50ddc404a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb07860fe97cfb30d33d48a50ddc404a = L.map(
#                 &quot;map_cb07860fe97cfb30d33d48a50ddc404a&quot;,
#                 {
#                     center: [38.7169, -9.1399],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_db018298bfc8cfa7c1fa16698b9ef526 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_db018298bfc8cfa7c1fa16698b9ef526.addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#             tile_layer_db018298bfc8cfa7c1fa16698b9ef526.addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#             var marker_37352640aa66320daa8b17014fab360b = L.marker(
#                 [38.6916, -9.215],
#                 {
# }
#             ).addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#         var popup_9c52efd7e2b9f26d171a4b83464e539c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_58e0ac39c6f0645af84e319cf996d140 = $(`&lt;div id=&quot;html_58e0ac39c6f0645af84e319cf996d140&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Torre de Belém&lt;/div&gt;`)[0];
#                 popup_9c52efd7e2b9f26d171a4b83464e539c.setContent(html_58e0ac39c6f0645af84e319cf996d140);
#
#
#
#         marker_37352640aa66320daa8b17014fab360b.bindPopup(popup_9c52efd7e2b9f26d171a4b83464e539c)
#         ;
#
#
#
#
#             marker_37352640aa66320daa8b17014fab360b.bindTooltip(
#                 `&lt;div&gt;
#                      Torre de Belém
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_43b79ee69a0bde937765aa580df3f55d = L.marker(
#                 [38.6972, -9.2065],
#                 {
# }
#             ).addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#         var popup_48e0ac46768163eefc8ac0acce9871e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_942bb967a552f283c2d59bf08a2994ac = $(`&lt;div id=&quot;html_942bb967a552f283c2d59bf08a2994ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mosteiro dos Jerónimos&lt;/div&gt;`)[0];
#                 popup_48e0ac46768163eefc8ac0acce9871e7.setContent(html_942bb967a552f283c2d59bf08a2994ac);
#
#
#
#         marker_43b79ee69a0bde937765aa580df3f55d.bindPopup(popup_48e0ac46768163eefc8ac0acce9871e7)
#         ;
#
#
#
#
#             marker_43b79ee69a0bde937765aa580df3f55d.bindTooltip(
#                 `&lt;div&gt;
#                      Mosteiro dos Jerónimos
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_683220093931f941c3a2d396b49e0d82 = L.marker(
#                 [38.7139, -9.1335],
#                 {
# }
#             ).addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#         var popup_5bd6a634b92f8d7fcc260ac701004edc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb10ffb6f6ed759b0a74048eb7e5c72f = $(`&lt;div id=&quot;html_cb10ffb6f6ed759b0a74048eb7e5c72f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Castelo de São Jorge&lt;/div&gt;`)[0];
#                 popup_5bd6a634b92f8d7fcc260ac701004edc.setContent(html_cb10ffb6f6ed759b0a74048eb7e5c72f);
#
#
#
#         marker_683220093931f941c3a2d396b49e0d82.bindPopup(popup_5bd6a634b92f8d7fcc260ac701004edc)
#         ;
#
#
#
#
#             marker_683220093931f941c3a2d396b49e0d82.bindTooltip(
#                 `&lt;div&gt;
#                      Castelo de São Jorge
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_afab9a952524c1d7fa2d9c04ed4a67ab = L.marker(
#                 [38.7078, -9.1366],
#                 {
# }
#             ).addTo(map_cb07860fe97cfb30d33d48a50ddc404a);
#
#
#         var

# %% [markdown]
# # Save the Final Map
# Save the final map as an HTML file using `mapa.save("meu_mapa.html")`.

# %%
# Save the Final Map
mapa.save(r'C:\Users\HP\Desktop\Formação\Eisnt\UFCD 10809 - Visualização de dados em Python\meu_mapa3.html')
